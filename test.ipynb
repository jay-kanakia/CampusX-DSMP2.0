# %% [markdown]
# <a href="https://colab.research.google.com/github/jay-kanakia/CampusX-DSMP2.0/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this is a test file

# %%
|
