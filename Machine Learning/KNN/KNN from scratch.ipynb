# %% [markdown]
# #### **Types of Distances**
# - `Linear Distance`: When you are more concerned about the `magnitude` of the difference between the points, you use linear distance. Used in `KNN` and `K-Means` clustering.
#
# - `Angular Distance`: When you are more concerned about the `direction` of the difference between the points, you use angular distance. Used in `Recommendation Systems` and the problems which requires `directional similarity`.
