# %%
# BuiltIn Modules - Came along with python installation
# math
import math
math.sqrt(196)
# Out:
# 14.0

# %%
# keyword
import keyword
print(keyword.kwlist) # Return all the keywords in python
print(f"Total Keywords: {len(keyword.kwlist)}")
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# Total Keywords: 35

# %%
# random
import random
print(random.randint(1,100))
# Out:
# 90

# %%
# datetime
import datetime
print(datetime.datetime.now())
# Out:
# 2025-12-12 12:56:23.408623

# %%
# External module - Explictly needs to be installed using pip inorder to use them.
import pandas
df = pandas.read_csv("one.csv")

# %%
# Import the train_test_split function from scikit-learn's model_selection module.
from sklearn.model_selection import train_test_split as tts  # Importing required functions only.

# %% [markdown]
# <i>pip is the package installer for Python."pip" does not have a universally accepted full form in Python. It allows you to install, manage, and update Python libraries and packages from the Python Package Index (PyPI) and other repositories. Essentially, it's a tool that helps you easily add external libraries to your Python environment, which can provide additional functionality or simplify development tasks.</i>

# %%
help('modules') # List of all the modules provided by python including the ones we have installed
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.50.4
# External Packages   _warnings           keyword             symtable
# IPython             _weakref            linecache           sys
# Taking Input        _weakrefset         locale              sysconfig
# Typecasting         _win32sysloader     logging             tabnanny
# __future__          _win32verstamp_pywin32ctypes lzma                tarfile
# __hello__           _winapi             mailbox             tempfile
# __phello__          _winxptheme         marshal             test
# _abc                _wmi                math                textwrap
# _aix_support        _zoneinfo           matplotlib_inline   this
# _android_support    abc                 mimetypes           threading
# _apple_support      adodbapi            mmap                time
# _ast                afxres              mmapfile            timeit
# _asyncio            antigravity         mmsystem            timer
# _bisect             argparse            modulefinder        tkinter
# _blake2             array               msvcrt              token
# _bz2                ast                 multiprocessing     tokenize
# _codecs             asttokens           nest_asyncio        tomllib
# _codecs_cn          asyncio             netbios             tornado
# _codecs_hk          atexit              netrc               trace
# _codecs_iso2022     base64              nt                  traceback
# _codecs_jp          bdb                 ntpath              tracemalloc
# _codecs_kr          binascii            ntsecuritycon       traitlets
# _codecs_tw          bisect              nturl2path          tty
# _collections        builtins            numbers             turtle
# _collections_abc    bz2                 odbc                turtledemo
# _colorize           cProfile            opcode              types
# _compat_pickle      calendar            operator            typing
# _compression        cmath               optparse            unicodedata
# _contextvars        cmd                 os                  unittest
# _csv                code                packaging           urllib
# _ctypes             codecs              parso               uuid
# _ctypes_test        codeop              pathlib             venv
# _datetime           collections         pdb                 warnings
# _decimal            colorama            perfmon             wave
# _elementtree        colorsys            pickle              wcwidth
# _functools          comm                pickletools         weakref
# _hashlib            commctrl            pip                 webbrowser
# _heapq              compileall          pkgutil             win2kras
# _imp                concurrent          platform            win32api
# _interpchannels     configparser        platformdirs        win32clipboard
# _interpqueues       contextlib          plistlib            win32com
# _interpreters       contextvars         poplib              win32con
# _io                 copy                posixpath           win32console
# _ios_support        copyreg             pprint              win32cred
# _json               csv                 profile             win32crypt
# _locale             ctypes              prompt_toolkit      win32cryptcon
# _lsprof             curses              pstats              win32event
# _lzma               dataclasses         psutil              win32evtlog
# _markupbase         datetime            pty                 win32evtlogutil
# _md5                dateutil            pure_eval           win32file
# _multibytecodec     dbm                 py_compile          win32gui
# _multiprocessing    dde                 pyclbr              win32gui_struct
# _opcode             debugpy             pydoc               win32help
# _opcode_metadata    decimal             pydoc_data          win32inet
# _operator           decorator           pyexpat             win32inetcon
# _osx_support        difflib             pygments            win32job
# _overlapped         dis                 pythoncom           win32lz
# _pickle             doctest             pywin               win32net
# _py_abc             email               pywin32_bootstrap   win32netcon
# _pydatetime         encodings           pywin32_testutil    win32pdh
# _pydecimal          ensurepip           pywintypes          win32pdhquery
# _pyio               enum                queue               win32pdhutil
# _pylong             errno               quopri              win32pipe
# _pyrepl             executing           random              win32print
# _queue              faulthandler        rasutil             win32process
# _random             filecmp             re                  win32profile
# _sha1               fileinput           regcheck            win32ras
# _sha2               fnmatch             regutil             win32rcparser
# _sha3               fractions           reprlib             win32security
# _signal             ftplib              rlcompleter         win32service
# _sitebuiltins       functools           runpy               win32serviceutil
# _socket             gc                  sched               win32timezone
# _sqlite3            genericpath         secrets             win32trace
# _sre                getopt              select              win32traceutil
# _ssl                getpass             selectors           win32transaction
# _stat               gettext             servicemanager      win32ts
# _statistics         glob                shelve              win32ui
# _string             graphlib            shlex               win32uiole
# _strptime           gzip                shutil              win32verstamp
# _struct             hashlib             signal              win32wnet
# _suggestions        heapq               site                winerror
# _symtable           hmac                six                 winioctlcon
# _sysconfig          html                smtplib             winnt
# _testbuffer         http                socket              winperf
# _testcapi           idlelib             socketserver        winreg
# _testclinic         imaplib             sqlite3             winsound
# _testclinic_limited importlib           sre_compile         winxpgui
# _testconsole        inspect             sre_constants       winxptheme
# _testimportmultiple io                  sre_parse           wsgiref
# _testinternalcapi   ipaddress           ssl                 xml
# _testlimitedcapi    ipykernel           sspi                xmlrpc
# _testmultiphase     ipykernel_launcher  sspicon             xxsubtype
# _testsinglephase    ipython_pygments_lexers stack_data          zipapp
# _thread             isapi               start_pythonwin     zipfile
# _threading_local    itertools           stat                zipimport
# _tkinter            jedi                statistics          zlib
# _tokenize           json                string              zmq
# _tracemalloc        jupyter             stringprep          zoneinfo
# _typing             jupyter_client      struct
# _uuid               jupyter_core        subprocess
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
